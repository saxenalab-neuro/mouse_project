# %% [markdown]
# Welcome to the mouse model demo!
# To begin training our mouse, we will first find and process the proper data. In the following segment, we select the fastest cycle speed found under data, select the time points we chose, and scale it. In the environment script, we select timepoints and scale the data.

# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt

mat = scipy.io.loadmat('../data/kinematics_session_mean_alt_fast.mat')
data = np.array(mat['kinematics_session_mean'][2])
data_fast = data[231:401:1] * -1
data_fast_plot = (data_fast/22) + .689

plt.axes(xlabel='Time points', ylabel = 'X-coord value')
plt.plot(data_fast_plot)
plt.show()
# Out:
# /home/andrea/anaconda3/envs/mouse/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# Next we will pip install the necessary reops, as per installation guide.

# %%
# %cd ~/mouse_project
# %cd bullet3
# %pip install -e .
# %cd ../farms_pylog
# %pip install -e .
# %cd ../farms_container
# %pip install -e .
# %cd ../farms_muscle
# %pip install -e .
# %cd ../scripts
# Out:
# /home/andrea/mouse_project
# /home/andrea/mouse_project/bullet3
# Obtaining file:///home/andrea/mouse_project/bullet3
#   Preparing metadata (setup.py) ... done
# /home/andrea/anaconda3/envs/mouse/lib/python3.10/site-packages/pip/_internal/metadata/pkg_resources.py:250: UserWarning: Unbuilt egg for RL-Framework-Mujoco-3 [unknown version] (/home/andrea/RL_Distributed_Test/gym-RL_Framework_Mujoco_3)
#   self._ws.require(name)
# WARNING: Error parsing requirements for rl-framework-mujoco-3: ("Missing 'Version:' header and/or PKG-INFO file at path: /home/andrea/RL_Distributed_Test/gym-RL_Framework_Mujoco_3/RL_Framework_Mujoco_3.egg-info/PKG-INFO", RL-Framework-Mujoco-3 [unknown version] (/home/andrea/RL_Distributed_Test/gym-RL_Framework_Mujoco_3))
# Installing collected packages: pybullet
#   Running setup.py develop for pybullet
# Successfully installed pybullet-3.2.5
# Note: you may need to restart the kernel to use updated packages.
# /home/andrea/mouse_project/farms_pylog
# Obtaining file:///home/andrea/mouse_project/farms_pylog
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: colorama in /home/andrea/anaconda3/envs/mouse/lib/python3.10/site-packages (from farms-pylog==0.1) (0.4.5)
# WARNING: Error parsing requirements for rl-framework-mujoco-3: ("Missing 'Version:' header and/or PKG-INFO file at path: /home/andrea/RL_Distributed_Test/gym-RL_Framework_Mujoco_3/RL_Framework_Mujoco_3.egg-info/PKG-INFO", RL-Framework-Mujoco-3 [unknown version] (/home/andrea/RL_Distributed_Test/gym-RL_Framework_Mujoco_3))
# Installing collected packages: farms-pylog
#   Attempting uninstall: farms-pylog
#     Found existing installation: farms-pylog 0.1
#     Uninstalling farms-pylog-0.1:
#       Successfully uninstalled farms-pylog-0.1
#   Running setup.py develop for farms-pylog
# /home/andrea/anaconda3/envs/mouse/lib/python3.10/site-packages/pip/_internal/metadata/pkg_resources.py:250: UserWarning: Unbuilt egg for RL-Framework-Mujoco-3 [unknown version] (/home/andrea/RL_Distributed_Test/gym-RL_Framework_Mujoco_3)
#   self._ws.require(name)
# Successfully installed farms-pylog-0.1
# Note: you may need to restart the kernel to use updated packages.
# /home/andrea/mouse_project/farms_container
# Obtaining file:///home/andrea/mouse_project/farms_container
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Collecting farms-pylog@ git+https://gitlab.com/FARMSIM/farms_pylog.git
#   Cloning https://gitlab.com/FARMSIM/farms_pylog.git to /tmp/pip-install-jtjw5e7x/farms-pylog_20de7dd467e84fc4bf59b71def9de721
#   Running command git clone --filter=blob:none --quiet https://gitlab.com/FARMSIM/farms_pylog.git /tmp/pip-install-jtjw5e7x/farms-pylog_20de7dd467e84fc4bf59b71def9de721
#   Resolved https://gitlab.com/FARMSIM/farms_pylog.git to commit b8e206a1cfe12c34198e4fe150dba5671e726232
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /home/andrea/anaconda3/envs/mouse/lib/python3.10/site-packages (from farms-container==0.1) (1.23.4)
# Requirement already satisfied: pandas in /home/andrea/anaconda3/envs/mouse/lib/python3.10/site-packages (from farms-container==0.1) (1.4.3)
# Requirement already satisfied: Cython in /home/andrea/anaconda3/envs/mouse/lib/python3.10/site-packages (from farms-container==0.1) (0.29.28)
# Requirement already satisfied: colorama in /home/andrea/anaconda3/envs/mouse/lib/python3.10/site-packages (from farms-pylog@ git+https://gitlab.com/FARMSIM/farms_pylog.git->farms-container==0.1) (0.4.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/andrea/anaconda3/envs/mouse/lib/python3.10/site-packages (from pandas->farms-container==0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/andrea/anaconda3/envs/mouse/lib/python3.10/site-packages (from pandas->farms-container==0.1) (2022.1)
# Requirement already satisfied: six>=1.5 in /home/andrea/anaconda3/envs/mouse/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->farms-container==0.1) (1.16.0)
# Building wheels for collected packages: farms-container, farms-pylog
#   Building editable for farms-container (pyproject.toml) ... done
#   Created wheel for farms-container: filename=farms_container-0.1-0.editable-cp310-cp310-linux_x86_64.whl size=2554 sha256=c0e701c05e7174db6e0fe840586abfd2e84df84143bd6b4986b8da70c2de3ea9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-z3u9gnko/wheels/38/70/15/39c08da5faa8b400508f97c68124ef1ec4ee7d8552565b558a
#   Building wheel for farms-pylog (setup.py) ... done
#   Created wheel for farms-pylog: filename=farms_pylog-0.1-py3-none-any.whl size=2984 sha256=97d30a4188af7588f65e0b9653a93551f0071d9bed2df516d60ad61dfd05d14c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-z3u9gnko/wheels/e1/ca/29/0aa2623d5fd0bf781bf23b5498738041d3aa815ff0a02f7b96
# Successfully built farms-container farms-pylog
# WARNING: Error parsing requirements for rl-framework-mujoco-3: ("Missing 'Version:' header and/or PKG-INFO file at path: /home/andrea/RL_Distributed_Test/gym-RL_Framework_Mujoco_3/RL_Framework_Mujoco_3.egg-info/PKG-INFO", RL-Framework-Mujoco-3 [unknown version] (/home/andrea/RL_Distributed_Test/gym-RL_Framework_Mujoco_3))
# Installing collected packages: farms-pylog, farms-container
#   Attempting uninstall: farms-pylog
#     Found existing installation: farms-pylog 0.1
#     Uninstalling farms-pylog-0.1:
#       Successfully uninstalled farms-pylog-0.1
#   Attempting uninstall: farms-container
#     Found existing installation: farms-container 0.1
#     Uninstalling farms-container-0.1:
#       Successfully uninstalled farms-container-0.1
# Successfully installed farms-container-0.1 farms-pylog-0.1
# Note: you may need to restart the kernel to use updated packages.
# /home/andrea/mouse_project/farms_muscle
# Obtaining file:///home/andrea/mouse_project/farms_muscle
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [30 lines of output]
#       Compiling farms_muscle/muscle.pyx because it depends on /home/andrea/anaconda3/envs/mouse/lib/python3.10/site-packages/numpy/__init__.pxd.
#       Compiling farms_muscle/geyer_muscle.pyx because it depends on /home/andrea/anaconda3/envs/mouse/lib/python3.10/site-packages/numpy/__init__.pxd.
#       Compiling farms_muscle/millard_rigid_tendon_muscle.pyx because it depends on /home/andrea/anaconda3/envs/mouse/lib/python3.10/site-packages/numpy/__init__.pxd.
#       Compiling farms_muscle/millard_damped_equillibrium_muscle.pyx because it depends on /home/andrea/anaconda3/envs/mouse/lib/python3.10/site-packages/numpy/__init__.pxd.
#       Compiling farms_muscle/muscle_system.pyx because it depends on /home/andrea/anaconda3/envs/mouse/lib/python3.10/site-packages/numpy/__init__.pxd.
#       Compiling farms_muscle/degroote_muscle.pyx because it changed.
#       Compiling farms_muscle/bullet_interface.pyx because it depends on /home/andrea/anaconda3/envs/mouse/lib/python3.10/site-packages/numpy/__init__.pxd.
#       [1/7] Cythonizing farms_muscle/degroote_muscle.pyx
#       /home/andrea/anaconda3/envs/mouse/lib/python3.10/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /home/andrea/mouse_project/farms_muscle/farms_muscle/degroote_muscle.pxd
#         tree = Parsing.p_module(s, pxd, full_module_name)
#
#       Error compiling Cython file:
#       ------------------------------------------------------------
#       ...
#       """Implementation of Geyer muscle model."""
#       from farms_container.parameter cimport Parameter
#       ^
#       ------------------------------------------------------------
#
#       farms_muscle/degroote_muscle.pxd:2:0: 'farms_container/parameter.pxd' not found
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/home/andrea/mouse_project/farms_muscle/setup.py", line 81, in <module>
#           ext_modules=cythonize(extensions, annotate=False),
#         File "/home/andrea/anaconda3/envs/mouse/lib/python3.10/site-packages/Cython/Build/Dependencies.py", line 1127, in cythonize
#           cythonize_one(*args)
#         File "/home/andrea/anaconda3/envs/mouse/lib/python3.10/site-packages/Cython/Build/Dependencies.py", line 1250, in cythonize_one
#           raise CompileError(None, pyx_file)
#       Cython.Compiler.Errors.CompileError: farms_muscle/degroote_muscle.pyx
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Note: you may need to restart the kernel to use updated packages.
# /home/andrea/mouse_project/scripts

# %% [markdown]
# Next, we will begin by defining our parameters. We have an array of indices (called ctrl) that correspond to the joints we are observing:
# -RShoulder_rotation - 107
# -RShoulder_adduction - 108
# -RShoulder_flexion - 109
# -RElbow_flexion - 110
# -RElbow_supination - 111
# -RWrist_adduction - 113
# -RWrist_flexion - 114
# -RMetacarpus1_flexion - 115, use link (carpus) for pos

# %%
import pybullet as p
import time
import argparse
import itertools
import torch
import numpy as np

import farms_pylog as pylog
import model_utils as model_utils
from Mouse_RL_Environment import Mouse_Env
from SAC.replay_memory import PolicyReplayMemory
from SAC.sac import SAC

file_path = "../model_utilities/mouse_fixed.sdf" # mouse model, body fixed except for right arm
pose_file = "../model_utilities/right_forelimb_pose.yaml" # pose file for original pose
muscle_config_file = "../model_utilities/right_forelimb.yaml" # muscle file for right arm

model_offset = (0.0, 0.0, .0475) #z position modified with global scaling

#ARM CONTROL
ctrl = [107, 108, 109, 110, 111, 113, 114]

parser = argparse.ArgumentParser(description='PyTorch Soft Actor-Critic Args')
parser.add_argument('--env-name', default="HalfCheetah-v2",
                    help='Mujoco Gym environment (default: HalfCheetah-v2)')
parser.add_argument('--policy', default="Gaussian",
                    help='Policy Type: Gaussian | Deterministic (default: Gaussian)')
parser.add_argument('--eval', type=bool, default=False,
                    help='Evaluates a policy a policy every 10 episode (default: True)')
parser.add_argument('--gamma', type=float, default=0.99, metavar='G',
                    help='discount factor for reward (default: 0.99)')
parser.add_argument('--tau', type=float, default=0.005, metavar='G',
                    help='target smoothing coefficient(τ) (default: 0.005)')
parser.add_argument('--lr', type=float, default=0.001, metavar='G',
                    help='learning rate (default: 0.001)')
parser.add_argument('--alpha', type=float, default=0.2, metavar='G',
                    help='Temperature parameter α determines the relative importance of the entropy\
                            term against the reward (default: 0.2)')
parser.add_argument('--automatic_entropy_tuning', type=bool, default=False, metavar='G',
                    help='Automaically adjust α (default: False)')
parser.add_argument('--seed', type=int, default=123456, metavar='N',
                    help='random seed (default: 123456)')
parser.add_argument('--policy_batch_size', type=int, default=256, metavar='N',
                    help='batch size (default: 6)')
parser.add_argument('--num_steps', type=int, default=1000001, metavar='N',
                    help='maximum number of steps (default: 1000000)')
parser.add_argument('--hidden_size', type=int, default=256, metavar='N',
                    help='hidden size (default: 1000)')
parser.add_argument('--updates_per_step', type=int, default=1, metavar='N',
                    help='model updates per simulator step (default: 1)')
parser.add_argument('--start_steps', type=int, default=0, metavar='N',
                    help='Steps sampling random actions (default: 10000)')
parser.add_argument('--target_update_interval', type=int, default=1, metavar='N',
                    help='Value target update per no. of updates per step (default: 1)')
parser.add_argument('--policy_replay_size', type=int, default=4000, metavar='N',
                    help='size of replay buffer (default: 2800)')
parser.add_argument('--cuda', action="store_true",
                    help='run on CUDA (default: False)')
args = parser.parse_args()

###PARAMETERS###
frame_skip = 1
n_frames = 1
timestep = 170
vizualize = True

# Training Loop
total_numsteps = 0
updates = 0
score_history= []
reward_tracker = []
test_history= []
vel_his = []
target_trajectory = []
env_counter_his= []
kinematics_x = []
kinematics_y = []
kinematics_z = []

reward_tracker = []
policy_loss_tracker = []

highest_reward = 0
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/andrea/mouse_project/scripts/demo.ipynb Cell 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/andrea/mouse_project/scripts/demo.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> import pybullet as p
#       <a href='vscode-notebook-cell:/home/andrea/mouse_project/scripts/demo.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> import time
#       <a href='vscode-notebook-cell:/home/andrea/mouse_project/scripts/demo.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> import argparse
#
# ModuleNotFoundError: No module named 'pybullet'

# %% [markdown]
# Next we will begin the simulation by initializing the environment, agent, and policy memory. We will also begin simulation of a trained model.

# %%
mouseEnv = Mouse_Env(file_path, muscle_config_file, pose_file, frame_skip, ctrl, timestep, model_offset, vizualize)
agent = SAC(41, mouseEnv.action_space, args)
policy_memory= torch.load('../models/policy_net_003_-30.pth')

torch.manual_seed(args.seed)
np.random.seed(args.seed)

model_utils.disable_control(mouseEnv.model)
p.setTimeStep(.001)

data_fast = data[231:401:1] * -1
data_fast_cycles = [*data_fast, *data_fast, *data_fast]

mouseEnv.timestep = len(data_fast_cycles)
mouseEnv.x_pos = data_fast_cycles

for i_episode in itertools.count(1):

    episode_reward = 0
    episode_steps = 0
    action_list= []
    done = False

    mouseEnv.reset(pose_file)
    state = mouseEnv.get_cur_state()
    ep_trajectory = []

#num_layers specified in the policy model 
    h_prev = torch.zeros(size=(1, 1, args.hidden_size))
    c_prev = torch.zeros(size=(1, 1, args.hidden_size))

    for i in range(mouseEnv.timestep):

        action, h_current, c_current = agent.select_action(state, h_prev, c_prev)  # Sample action from policy

        action_list.append(action)

        
        next_state, reward, done = mouseEnv.step(action, i_episode)

        episode_reward += reward

        mask = 1 if episode_steps == mouseEnv._max_episode_steps else float(not done)

        if episode_steps == 0:
            ep_trajectory.append((state, action, np.array([reward]), next_state, np.array([mask]), h_prev, c_prev, h_current, c_current))
        else:
            ep_trajectory.append((state, action, np.array([reward]), next_state, np.array([mask])))

        state = next_state
        h_prev = h_current
        c_prev = c_current

        episode_steps += 1
        total_numsteps += 1 

        if done:
            break
    
    if episode_reward > highest_reward:
        highest_reward = episode_reward 

    #pylog.debug("Saving policy and Q network")
    #torch.save(agent.policy.state_dict(), '../models/policy_net.pth')
    #torch.save(agent.critic.state_dict(), '../models/value_net.pth')

    pylog.debug('reward at total timestep {}: {}'.format(mouseEnv.timestep, episode_reward))
    pylog.debug('highest reward so far: {}'.format(highest_reward))
    reward_tracker.append(episode_reward)
    
    policy_memory.push(ep_trajectory)
        
mouseEnv.close() #disconnects server
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/andrea/mouse_project/scripts/demo.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/andrea/mouse_project/scripts/demo.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> mouseEnv = Mouse_Env(file_path, muscle_config_file, pose_file, frame_skip, ctrl, timestep, model_offset, vizualize)
#       <a href='vscode-notebook-cell:/home/andrea/mouse_project/scripts/demo.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> agent = SAC(41, mouseEnv.action_space, args)
#       <a href='vscode-notebook-cell:/home/andrea/mouse_project/scripts/demo.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> policy_memory= PolicyReplayMemory(args.policy_replay_size, args.seed)
#
# NameError: name 'Mouse_Env' is not defined
